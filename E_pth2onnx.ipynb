# %%
# conda environment

import os
import onnxruntime as ort

# %%
# !rm -rf mmdeploy
# !git clone https://github.com/open-mmlab/mmdeploy.git

# %%
def config(dataset, model):
    if dataset == 'cityscapes':
        if model == 'UNet':
            # Unet
            config_file = './mmdeploy/configs/unet/unet-s5-d16_fcn_4xb4-160k_cityscapes-512x1024.py'
            checkpoint_file = 'https://download.openmmlab.com/mmsegmentation/v0.5/unet/fcn_unet_s5-d16_4x4_512x1024_160k_cityscapes/fcn_unet_s5-d16_4x4_512x1024_160k_cityscapes_20211210_145204-6860854e.pth'
        elif model == 'DeepLabV3+':
            # DeepLabV3+, R-50-D8	512x1024
            config_file = './mmdeploy/configs/deeplabv3plus/deeplabv3plus_r50-d8_4xb2-80k_cityscapes-512x1024.py'
            checkpoint_file = 'https://download.openmmlab.com/mmsegmentation/v0.5/deeplabv3plus/deeplabv3plus_r50-d8_512x1024_80k_cityscapes/deeplabv3plus_r50-d8_512x1024_80k_cityscapes_20200606_114049-f9fb496d.pth'
        elif model == 'FastSCNN':
            # FastSCNN
            config_file = './mmdeploy/configs/fastscnn/fast_scnn_8xb4-160k_cityscapes-512x1024.py'
            checkpoint_file = 'https://download.openmmlab.com/mmsegmentation/v0.5/fast_scnn/fast_scnn_lr0.12_8x4_160k_cityscapes/fast_scnn_lr0.12_8x4_160k_cityscapes_20210630_164853-0cec9937.pth'
        elif model == 'SegFormer':
            # SegFormer, MIT-B5	1024x1024	
            config_file = './mmdeploy/configs/segformer/segformer_mit-b5_8xb1-160k_cityscapes-1024x1024.py'
            checkpoint_file = 'https://download.openmmlab.com/mmsegmentation/v0.5/segformer/segformer_mit-b5_8x1_1024x1024_160k_cityscapes/segformer_mit-b5_8x1_1024x1024_160k_cityscapes_20211206_072934-87a052ec.pth'
        elif model == 'Mask2Former':
            # Mask2Former, Swin-B (in22k)	512x1024	
            config_file = './mmdeploy/configs/mask2former/mask2former_swin-b-in22k-384x384-pre_8xb2-90k_cityscapes-512x1024.py'
            checkpoint_file = 'https://download.openmmlab.com/mmsegmentation/v0.5/mask2former/mask2former_swin-b-in22k-384x384-pre_8xb2-90k_cityscapes-512x1024/mask2former_swin-b-in22k-384x384-pre_8xb2-90k_cityscapes-512x1024_20221203_045030-9a86a225.pth'
    elif dataset == 'ade20K':
        if model == 'DeepLabV3+':
            config_file = './mmdeploy/configs/deeplabv3plus/deeplabv3plus_r50-d8_4xb4-80k_ade20k-512x512.py'
            checkpoint_file = 'https://download.openmmlab.com/mmsegmentation/v0.5/deeplabv3plus/deeplabv3plus_r50-d8_512x512_80k_ade20k/deeplabv3plus_r50-d8_512x512_80k_ade20k_20200614_185028-bf1400d8.pth'
        elif model == 'pspnet':
            config_file ='./mmdeploy/configs/pspnet/pspnet_r50-d8_4xb4-80k_ade20k-512x512.py'
            checkpoint_file = 'https://download.openmmlab.com/mmsegmentation/v0.5/pspnet/pspnet_r50-d8_512x512_160k_ade20k/pspnet_r50-d8_512x512_160k_ade20k_20200615_184358-1890b0bd.pth'
        elif model == 'SegFormer':
            config_file = './mmdeploy/configs/segformer/segformer_mit-b5_8xb2-160k_ade20k-512x512.py'
            checkpoint_file = 'https://download.openmmlab.com/mmsegmentation/v0.5/segformer/segformer_mit-b5_512x512_160k_ade20k/segformer_mit-b5_512x512_160k_ade20k_20210726_145235-94cedf59.pth'
        elif model == 'MaskFormer':
            config_file = './mmdeploy/configs/maskformer/maskformer_swin-s_upernet_8xb2-160k_ade20k-512x512.py'
            checkpoint_file = 'https://download.openmmlab.com/mmsegmentation/v0.5/maskformer/maskformer_swin-s_upernet_8xb2-160k_ade20k-512x512/maskformer_swin-s_upernet_8xb2-160k_ade20k-512x512_20221115_114710-723512c7.pth'
        elif model == 'Mask2Former':
            config_file = './mmdeploy/configs/mask2former/mask2former_swin-b-in22k-384x384-pre_8xb2-160k_ade20k-640x640.py'
            checkpoint_file = 'https://download.openmmlab.com/mmsegmentation/v0.5/mask2former/mask2former_swin-b-in22k-384x384-pre_8xb2-160k_ade20k-640x640/mask2former_swin-b-in22k-384x384-pre_8xb2-160k_ade20k-640x640_20221203_235230-7ec0f569.pth'
        
    return config_file, checkpoint_file

# %% [markdown]
# ## cityscapes

# %% [markdown]
# ### Fast-SCNN

# %%
# !python ./mmdeploy/tools/deploy.py \
    ./mmdeploy/configs/mmseg/segmentation_onnxruntime_dynamic.py \
    './mmsegmentation/configs/fastscnn/fast_scnn_8xb4-160k_cityscapes-512x1024.py' \
    'https://download.openmmlab.com/mmsegmentation/v0.5/fast_scnn/fast_scnn_lr0.12_8x4_160k_cityscapes/fast_scnn_lr0.12_8x4_160k_cityscapes_20210630_164853-0cec9937.pth' \
    ./data/street_uk.jpeg \
    --work-dir ./outputs/mmseg2onnx_cityscapes_fastscnn \
    --dump-info
# Out:
# 09/17 23:08:16 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "Codebases" registry tree. As a workaround, the current "Codebases" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:08:16 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "mmseg_tasks" registry tree. As a workaround, the current "mmseg_tasks" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:08:17 - mmengine - INFO - Start pipeline mmdeploy.apis.pytorch2onnx.torch2onnx in subprocess
# 09/17 23:08:18 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "Codebases" registry tree. As a workaround, the current "Codebases" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:08:18 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "mmseg_tasks" registry tree. As a workaround, the current "mmseg_tasks" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/builder.py:36: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn('``build_loss`` would be deprecated soon, please use '
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/losses/cross_entropy_loss.py:235: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmsegmentation/v0.5/fast_scnn/fast_scnn_lr0.12_8x4_160k_cityscapes/fast_scnn_lr0.12_8x4_160k_cityscapes_20210630_164853-0cec9937.pth
# 09/17 23:08:18 - mmengine - WARNING - DeprecationWarning: get_onnx_config will be deprecated in the future.
# 09/17 23:08:18 - mmengine - INFO - Export PyTorch model to ONNX: ./outputs/mmseg2onnx_cityscapes_fastscnn/end2end.onnx.
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/core/optimizers/function_marker.py:160: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   ys_shape = tuple(int(s) for s in ys.shape)
# 09/17 23:08:19 - mmengine - WARNING - `adaptive_avg_pool2d` would be replaced to `avg_pool2d` explicitly
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/pytorch/functions/adaptive_pool.py:26: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   k = [int(size[i] / output_size[i]) for i in range(0, len(size))]
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/codebase/mmseg/models/segmentors/base.py:61: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if seg_logit.shape[1] == 1:
# 09/17 23:08:19 - mmengine - INFO - Execute onnx optimize passes.
# 09/17 23:08:19 - mmengine - WARNING - Can not optimize model, please build torchscipt extension.
# More details: https://github.com/open-mmlab/mmdeploy/tree/main/docs/en/experimental/onnx_optimizer.md
# ============= Diagnostic Run torch.onnx.export version 2.0.0+cu117 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# 09/17 23:08:19 - mmengine - INFO - Finish pipeline mmdeploy.apis.pytorch2onnx.torch2onnx
# 09/17 23:08:20 - mmengine - INFO - Start pipeline mmdeploy.apis.utils.utils.to_backend in main process
# 09/17 23:08:20 - mmengine - INFO - Finish pipeline mmdeploy.apis.utils.utils.to_backend
# 09/17 23:08:20 - mmengine - INFO - visualize onnxruntime model start.
# 09/17 23:08:22 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "Codebases" registry tree. As a workaround, the current "Codebases" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:08:22 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "mmseg_tasks" registry tree. As a workaround, the current "mmseg_tasks" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:08:22 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "backend_segmentors" registry tree. As a workaround, the current "backend_segmentors" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:08:22 - mmengine - INFO - Successfully loaded onnxruntime custom ops from /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/lib/libmmdeploy_onnxruntime_ops.so
# 09/17 23:08:23 - mmengine - INFO - visualize onnxruntime model success.
# 09/17 23:08:23 - mmengine - INFO - visualize pytorch model start.
# 09/17 23:08:25 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "Codebases" registry tree. As a workaround, the current "Codebases" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:08:25 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "mmseg_tasks" registry tree. As a workaround, the current "mmseg_tasks" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/builder.py:36: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn('``build_loss`` would be deprecated soon, please use '
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/losses/cross_entropy_loss.py:235: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmsegmentation/v0.5/fast_scnn/fast_scnn_lr0.12_8x4_160k_cityscapes/fast_scnn_lr0.12_8x4_160k_cityscapes_20210630_164853-0cec9937.pth
# 09/17 23:08:26 - mmengine - INFO - visualize pytorch model success.
# 09/17 23:08:26 - mmengine - INFO - All process success.

# %% [markdown]
# ### segformer

# %%
# !python ./mmdeploy/tools/deploy.py \
#     ./mmdeploy/configs/mmseg/segmentation_onnxruntime_dynamic.py \
#     './mmsegmentation/configs/segformer/segformer_mit-b5_8xb1-160k_cityscapes-1024x1024.py' \
#     'https://download.openmmlab.com/mmsegmentation/v0.5/segformer/segformer_mit-b5_8x1_1024x1024_160k_cityscapes/segformer_mit-b5_8x1_1024x1024_160k_cityscapes_20211206_072934-87a052ec.pth'\
#     ./data/street_uk.jpeg \
#     --work-dir ./outputs/mmseg2onnx_cityscapes_segformer \
#     --dump-info
# Out:
# 09/17 23:08:30 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "Codebases" registry tree. As a workaround, the current "Codebases" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:08:30 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "mmseg_tasks" registry tree. As a workaround, the current "mmseg_tasks" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:08:31 - mmengine - INFO - Start pipeline mmdeploy.apis.pytorch2onnx.torch2onnx in subprocess
# 09/17 23:08:32 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "Codebases" registry tree. As a workaround, the current "Codebases" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:08:32 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "mmseg_tasks" registry tree. As a workaround, the current "mmseg_tasks" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/builder.py:36: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn('``build_loss`` would be deprecated soon, please use '
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/losses/cross_entropy_loss.py:235: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmsegmentation/v0.5/segformer/segformer_mit-b5_8x1_1024x1024_160k_cityscapes/segformer_mit-b5_8x1_1024x1024_160k_cityscapes_20211206_072934-87a052ec.pth
# 09/17 23:08:33 - mmengine - WARNING - DeprecationWarning: get_onnx_config will be deprecated in the future.
# 09/17 23:08:33 - mmengine - INFO - Export PyTorch model to ONNX: ./outputs/mmseg2onnx_cityscapes_segformer/end2end.onnx.
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/core/optimizers/function_marker.py:160: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   ys_shape = tuple(int(s) for s in ys.shape)
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/utils/shape_convert.py:15: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert L == H * W, 'The seq_len doesn\'t match H, W'
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmcv/cnn/bricks/wrappers.py:44: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if x.numel() == 0 and obsolete_torch_version(TORCH_VERSION, (1, 4)):
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/codebase/mmseg/models/segmentors/base.py:61: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if seg_logit.shape[1] == 1:
# ============= Diagnostic Run torch.onnx.export version 2.0.0+cu117 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 1 ERROR ========================
# ERROR: missing-standard-symbolic-function
# =========================================
# Exporting the operator 'aten::unflatten' to ONNX opset version 11 is not supported. Please feel free to request support or submit a pull request on PyTorch GitHub: https://github.com/pytorch/pytorch/issues.
# None
# <Set verbose=True to see more details>
#
#
# Process Process-2:
# Traceback (most recent call last):
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/core/pipeline_manager.py", line 107, in __call__
#     ret = func(*args, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/pytorch2onnx.py", line 98, in torch2onnx
#     export(
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/core/pipeline_manager.py", line 356, in _wrap
#     return self.call_function(func_name_, *args, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/core/pipeline_manager.py", line 326, in call_function
#     return self.call_function_local(func_name, *args, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/core/pipeline_manager.py", line 275, in call_function_local
#     return pipe_caller(*args, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/core/pipeline_manager.py", line 107, in __call__
#     ret = func(*args, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/onnx/export.py", line 131, in export
#     torch.onnx.export(
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/onnx/utils.py", line 506, in export
#     _export(
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/onnx/utils.py", line 1548, in _export
#     graph, params_dict, torch_out = _model_to_graph(
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/onnx/optimizer.py", line 27, in model_to_graph__custom_optimizer
#     graph, params_dict, torch_out = ctx.origin_func(*args, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/onnx/utils.py", line 1117, in _model_to_graph
#     graph = _optimize_graph(
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/onnx/utils.py", line 665, in _optimize_graph
#     graph = _C._jit_pass_onnx(graph, operator_export_type)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/onnx/utils.py", line 1901, in _run_symbolic_function
#     raise errors.UnsupportedOperatorError(
# torch.onnx.errors.UnsupportedOperatorError: Exporting the operator 'aten::unflatten' to ONNX opset version 11 is not supported. Please feel free to request support or submit a pull request on PyTorch GitHub: https://github.com/pytorch/pytorch/issues.
# 09/17 23:08:46 - mmengine - ERROR - /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/core/pipeline_manager.py - pop_mp_output - 80 - `mmdeploy.apis.pytorch2onnx.torch2onnx` with Call id: 0 failed. exit.

# %% [markdown]
# ### BiSeNetV2

# %%
# !python ./mmdeploy/tools/deploy.py \
    ./mmdeploy/configs/mmseg/segmentation_onnxruntime_dynamic.py \
    './mmsegmentation/configs/bisenetv2/bisenetv2_fcn_4xb4-160k_cityscapes-1024x1024.py' \
    'https://download.openmmlab.com/mmsegmentation/v0.5/bisenetv2/bisenetv2_fcn_4x4_1024x1024_160k_cityscapes/bisenetv2_fcn_4x4_1024x1024_160k_cityscapes_20210902_015551-bcf10f09.pth'\
    ./data/street_uk.jpeg \
    --work-dir ./outputs/mmseg2onnx_cityscapes_BiSeNetV2 \
    --dump-info
# Out:
# 09/17 23:08:51 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "Codebases" registry tree. As a workaround, the current "Codebases" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:08:51 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "mmseg_tasks" registry tree. As a workaround, the current "mmseg_tasks" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:08:52 - mmengine - INFO - Start pipeline mmdeploy.apis.pytorch2onnx.torch2onnx in subprocess
# 09/17 23:08:53 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "Codebases" registry tree. As a workaround, the current "Codebases" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:08:53 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "mmseg_tasks" registry tree. As a workaround, the current "mmseg_tasks" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/builder.py:36: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn('``build_loss`` would be deprecated soon, please use '
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/losses/cross_entropy_loss.py:235: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmsegmentation/v0.5/bisenetv2/bisenetv2_fcn_4x4_1024x1024_160k_cityscapes/bisenetv2_fcn_4x4_1024x1024_160k_cityscapes_20210902_015551-bcf10f09.pth
# 09/17 23:08:53 - mmengine - WARNING - DeprecationWarning: get_onnx_config will be deprecated in the future.
# 09/17 23:08:53 - mmengine - INFO - Export PyTorch model to ONNX: ./outputs/mmseg2onnx_cityscapes_BiSeNetV2/end2end.onnx.
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/core/optimizers/function_marker.py:160: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   ys_shape = tuple(int(s) for s in ys.shape)
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/codebase/mmseg/models/segmentors/base.py:61: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if seg_logit.shape[1] == 1:
# 09/17 23:08:55 - mmengine - INFO - Execute onnx optimize passes.
# 09/17 23:08:55 - mmengine - WARNING - Can not optimize model, please build torchscipt extension.
# More details: https://github.com/open-mmlab/mmdeploy/tree/main/docs/en/experimental/onnx_optimizer.md
# ============= Diagnostic Run torch.onnx.export version 2.0.0+cu117 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# 09/17 23:08:55 - mmengine - INFO - Finish pipeline mmdeploy.apis.pytorch2onnx.torch2onnx
# 09/17 23:08:55 - mmengine - INFO - Start pipeline mmdeploy.apis.utils.utils.to_backend in main process
# 09/17 23:08:55 - mmengine - INFO - Finish pipeline mmdeploy.apis.utils.utils.to_backend
# 09/17 23:08:55 - mmengine - INFO - visualize onnxruntime model start.
# 09/17 23:08:57 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "Codebases" registry tree. As a workaround, the current "Codebases" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:08:57 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "mmseg_tasks" registry tree. As a workaround, the current "mmseg_tasks" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:08:57 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "backend_segmentors" registry tree. As a workaround, the current "backend_segmentors" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:08:57 - mmengine - INFO - Successfully loaded onnxruntime custom ops from /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/lib/libmmdeploy_onnxruntime_ops.so
# 09/17 23:08:59 - mmengine - INFO - visualize onnxruntime model success.
# 09/17 23:08:59 - mmengine - INFO - visualize pytorch model start.
# 09/17 23:09:01 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "Codebases" registry tree. As a workaround, the current "Codebases" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:09:01 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "mmseg_tasks" registry tree. As a workaround, the current "mmseg_tasks" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/builder.py:36: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn('``build_loss`` would be deprecated soon, please use '
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/losses/cross_entropy_loss.py:235: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmsegmentation/v0.5/bisenetv2/bisenetv2_fcn_4x4_1024x1024_160k_cityscapes/bisenetv2_fcn_4x4_1024x1024_160k_cityscapes_20210902_015551-bcf10f09.pth
# 09/17 23:09:02 - mmengine - INFO - visualize pytorch model success.
# 09/17 23:09:02 - mmengine - INFO - All process success.

# %% [markdown]
# ### Mask2Former

# %%
# !python ./mmdeploy/tools/deploy.py \
#     ./mmdeploy/configs/mmseg/segmentation_onnxruntime_dynamic.py \
#     './mmsegmentation/configs/mask2former/mask2former_swin-b-in22k-384x384-pre_8xb2-90k_cityscapes-512x1024.py' \
#     'https://download.openmmlab.com/mmsegmentation/v0.5/mask2former/mask2former_swin-b-in22k-384x384-pre_8xb2-90k_cityscapes-512x1024/mask2former_swin-b-in22k-384x384-pre_8xb2-90k_cityscapes-512x1024_20221203_045030-9a86a225.pth' \
#     ./data/street_uk.jpeg \
#     --work-dir ./outputs/mmseg2onnx_cityscapes_mask2former \
#     --dump-info
# Out:
# 09/17 23:09:06 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "Codebases" registry tree. As a workaround, the current "Codebases" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:09:06 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "mmseg_tasks" registry tree. As a workaround, the current "mmseg_tasks" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:09:08 - mmengine - INFO - Start pipeline mmdeploy.apis.pytorch2onnx.torch2onnx in subprocess
# 09/17 23:09:08 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "Codebases" registry tree. As a workaround, the current "Codebases" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:09:08 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "mmseg_tasks" registry tree. As a workaround, the current "mmseg_tasks" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmsegmentation/v0.5/mask2former/mask2former_swin-b-in22k-384x384-pre_8xb2-90k_cityscapes-512x1024/mask2former_swin-b-in22k-384x384-pre_8xb2-90k_cityscapes-512x1024_20221203_045030-9a86a225.pth
# 09/17 23:09:09 - mmengine - WARNING - DeprecationWarning: get_onnx_config will be deprecated in the future.
# 09/17 23:09:09 - mmengine - INFO - Export PyTorch model to ONNX: ./outputs/mmseg2onnx_cityscapes_mask2former/end2end.onnx.
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/core/optimizers/function_marker.py:160: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   ys_shape = tuple(int(s) for s in ys.shape)
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/utils/embed.py:62: TracerWarning: Converting a tensor to a Python float might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   output_h = math.ceil(input_h / stride_h)
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/utils/embed.py:63: TracerWarning: Converting a tensor to a Python float might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   output_w = math.ceil(input_w / stride_w)
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/utils/embed.py:64: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   pad_h = max((output_h - 1) * stride_h +
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/utils/embed.py:66: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   pad_w = max((output_w - 1) * stride_w +
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/utils/embed.py:72: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if pad_h > 0 or pad_w > 0:
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/backbones/swin.py:183: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert L == H * W, 'input feature has wrong size'
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/backbones/swin.py:266: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   B = int(windows.shape[0] / (H * W / window_size / window_size))
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/backbones/swin.py:248: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if pad_r > 0 or pad_b:
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmcv/cnn/bricks/wrappers.py:167: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if x.numel() == 0 and obsolete_torch_version(TORCH_VERSION, (1, 5)):
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/pytorch/functions/tensor_setitem.py:38: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   stop = stop if stop >= 0 else self_shape[i] + stop
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/utils/embed.py:306: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert L == H * W, 'input feature has wrong size'
# ============= Diagnostic Run torch.onnx.export version 2.0.0+cu117 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# Process Process-2:
# Traceback (most recent call last):
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/core/pipeline_manager.py", line 107, in __call__
#     ret = func(*args, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/pytorch2onnx.py", line 98, in torch2onnx
#     export(
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/core/pipeline_manager.py", line 356, in _wrap
#     return self.call_function(func_name_, *args, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/core/pipeline_manager.py", line 326, in call_function
#     return self.call_function_local(func_name, *args, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/core/pipeline_manager.py", line 275, in call_function_local
#     return pipe_caller(*args, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/core/pipeline_manager.py", line 107, in __call__
#     ret = func(*args, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/onnx/export.py", line 131, in export
#     torch.onnx.export(
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/onnx/utils.py", line 506, in export
#     _export(
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/onnx/utils.py", line 1548, in _export
#     graph, params_dict, torch_out = _model_to_graph(
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/onnx/optimizer.py", line 27, in model_to_graph__custom_optimizer
#     graph, params_dict, torch_out = ctx.origin_func(*args, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/onnx/utils.py", line 1113, in _model_to_graph
#     graph, params, torch_out, module = _create_jit_graph(model, args)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/onnx/utils.py", line 989, in _create_jit_graph
#     graph, torch_out = _trace_and_get_graph_from_model(model, args)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/onnx/utils.py", line 893, in _trace_and_get_graph_from_model
#     trace_graph, torch_out, inputs_states = torch.jit._get_trace_graph(
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/jit/_trace.py", line 1268, in _get_trace_graph
#     outs = ONNXTracedModule(f, strict, _force_outplace, return_inputs, _return_inputs_states)(*args, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/jit/_trace.py", line 127, in forward
#     graph, out = torch._C._create_graph_by_tracing(
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/jit/_trace.py", line 118, in wrapper
#     outs.append(self.inner(*trace_inputs))
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1488, in _slow_forward
#     result = self.forward(*input, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/onnx/export.py", line 123, in wrapper
#     return forward(*arg, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/codebase/mmseg/models/segmentors/base.py", line 51, in base_segmentor__forward
#     seg_logit = self.predict(inputs, data_samples)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/codebase/mmseg/models/segmentors/encoder_decoder.py", line 26, in encoder_decoder__predict
#     seg_logit = self.decode_head.predict(x, batch_img_metas, self.test_cfg)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/decode_heads/mask2former_head.py", line 146, in predict
#     batch_data_samples = [
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/decode_heads/mask2former_head.py", line 147, in <listcomp>
#     SegDataSample(metainfo=metainfo) for metainfo in batch_img_metas
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmengine/structures/base_data_element.py", line 216, in __init__
#     self.set_metainfo(metainfo=metainfo)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmengine/structures/base_data_element.py", line 231, in set_metainfo
#     meta = copy.deepcopy(metainfo)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/copy.py", line 146, in deepcopy
#     y = copier(x, memo)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/copy.py", line 231, in _deepcopy_dict
#     y[deepcopy(key, memo)] = deepcopy(value, memo)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/copy.py", line 172, in deepcopy
#     y = _reconstruct(x, memo, *rv)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/copy.py", line 265, in _reconstruct
#     y = func(*args)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/copy.py", line 264, in <genexpr>
#     args = (deepcopy(arg, memo) for arg in args)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/copy.py", line 146, in deepcopy
#     y = copier(x, memo)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/copy.py", line 211, in _deepcopy_tuple
#     y = [deepcopy(a, memo) for a in x]
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/copy.py", line 211, in <listcomp>
#     y = [deepcopy(a, memo) for a in x]
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/copy.py", line 153, in deepcopy
#     y = copier(memo)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/_tensor.py", line 118, in __deepcopy__
#     new_storage = self._typed_storage()._deepcopy(memo)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/storage.py", line 661, in _deepcopy
#     return self._new_wrapped_storage(copy.deepcopy(self._untyped_storage, memo))
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/copy.py", line 153, in deepcopy
#     y = copier(memo)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/storage.py", line 98, in __deepcopy__
#     new_storage = self.clone()
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/storage.py", line 112, in clone
#     return type(self)(self.nbytes(), device=self.device).copy_(self)
# RuntimeError: NYI: Named tensors are not supported with the tracer
# 09/17 23:09:16 - mmengine - ERROR - /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/core/pipeline_manager.py - pop_mp_output - 80 - `mmdeploy.apis.pytorch2onnx.torch2onnx` with Call id: 0 failed. exit.

# %% [markdown]
# ## ADE20K

# %% [markdown]
# ### pspnet

# %%
# !python ./mmdeploy/tools/deploy.py \
    ./mmdeploy/configs/mmseg/segmentation_onnxruntime_dynamic.py \
    './mmsegmentation/configs/pspnet/pspnet_r50-d8_4xb4-80k_ade20k-512x512.py' \
    'https://download.openmmlab.com/mmsegmentation/v0.5/pspnet/pspnet_r50-d8_512x512_160k_ade20k/pspnet_r50-d8_512x512_160k_ade20k_20200615_184358-1890b0bd.pth'\
    ./data/street_uk.jpeg \
    --work-dir ./outputs/mmseg2onnx_ade20k_pspnet \
    --dump-info
# Out:
# 09/17 23:09:20 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "Codebases" registry tree. As a workaround, the current "Codebases" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:09:20 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "mmseg_tasks" registry tree. As a workaround, the current "mmseg_tasks" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:09:21 - mmengine - INFO - Start pipeline mmdeploy.apis.pytorch2onnx.torch2onnx in subprocess
# 09/17 23:09:22 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "Codebases" registry tree. As a workaround, the current "Codebases" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:09:22 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "mmseg_tasks" registry tree. As a workaround, the current "mmseg_tasks" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/builder.py:36: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn('``build_loss`` would be deprecated soon, please use '
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/losses/cross_entropy_loss.py:235: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmsegmentation/v0.5/pspnet/pspnet_r50-d8_512x512_160k_ade20k/pspnet_r50-d8_512x512_160k_ade20k_20200615_184358-1890b0bd.pth
# 09/17 23:09:23 - mmengine - WARNING - DeprecationWarning: get_onnx_config will be deprecated in the future.
# 09/17 23:09:23 - mmengine - INFO - Export PyTorch model to ONNX: ./outputs/mmseg2onnx_ade20k_pspnet/end2end.onnx.
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/core/optimizers/function_marker.py:160: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   ys_shape = tuple(int(s) for s in ys.shape)
# 09/17 23:09:24 - mmengine - WARNING - `adaptive_avg_pool2d` would be replaced to `avg_pool2d` explicitly
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/pytorch/functions/adaptive_pool.py:26: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   k = [int(size[i] / output_size[i]) for i in range(0, len(size))]
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/codebase/mmseg/models/segmentors/base.py:61: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if seg_logit.shape[1] == 1:
# 09/17 23:09:25 - mmengine - INFO - Execute onnx optimize passes.
# 09/17 23:09:25 - mmengine - WARNING - Can not optimize model, please build torchscipt extension.
# More details: https://github.com/open-mmlab/mmdeploy/tree/main/docs/en/experimental/onnx_optimizer.md
# ============= Diagnostic Run torch.onnx.export version 2.0.0+cu117 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# 09/17 23:09:25 - mmengine - INFO - Finish pipeline mmdeploy.apis.pytorch2onnx.torch2onnx
# 09/17 23:09:25 - mmengine - INFO - Start pipeline mmdeploy.apis.utils.utils.to_backend in main process
# 09/17 23:09:25 - mmengine - INFO - Finish pipeline mmdeploy.apis.utils.utils.to_backend
# 09/17 23:09:25 - mmengine - INFO - visualize onnxruntime model start.
# 09/17 23:09:27 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "Codebases" registry tree. As a workaround, the current "Codebases" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:09:27 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "mmseg_tasks" registry tree. As a workaround, the current "mmseg_tasks" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:09:27 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "backend_segmentors" registry tree. As a workaround, the current "backend_segmentors" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:09:27 - mmengine - INFO - Successfully loaded onnxruntime custom ops from /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/lib/libmmdeploy_onnxruntime_ops.so
# 09/17 23:09:30 - mmengine - INFO - visualize onnxruntime model success.
# 09/17 23:09:30 - mmengine - INFO - visualize pytorch model start.
# 09/17 23:09:32 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "Codebases" registry tree. As a workaround, the current "Codebases" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:09:32 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "mmseg_tasks" registry tree. As a workaround, the current "mmseg_tasks" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/builder.py:36: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn('``build_loss`` would be deprecated soon, please use '
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/losses/cross_entropy_loss.py:235: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmsegmentation/v0.5/pspnet/pspnet_r50-d8_512x512_160k_ade20k/pspnet_r50-d8_512x512_160k_ade20k_20200615_184358-1890b0bd.pth
# 09/17 23:09:35 - mmengine - INFO - visualize pytorch model success.
# 09/17 23:09:35 - mmengine - INFO - All process success.

# %% [markdown]
# ### DeepLabV3+

# %%
# !python ./mmdeploy/tools/deploy.py \
    ./mmdeploy/configs/mmseg/segmentation_onnxruntime_dynamic.py \
    './mmsegmentation/configs/deeplabv3plus/deeplabv3plus_r50-d8_4xb4-80k_ade20k-512x512.py' \
    'https://download.openmmlab.com/mmsegmentation/v0.5/deeplabv3plus/deeplabv3plus_r50-d8_512x512_80k_ade20k/deeplabv3plus_r50-d8_512x512_80k_ade20k_20200614_185028-bf1400d8.pth'\
    ./data/street_uk.jpeg \
    --work-dir ./outputs/mmseg2onnx_ade20k_deeplabv3+ \
    --dump-info
# Out:
# 09/17 23:09:39 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "Codebases" registry tree. As a workaround, the current "Codebases" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:09:39 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "mmseg_tasks" registry tree. As a workaround, the current "mmseg_tasks" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:09:40 - mmengine - INFO - Start pipeline mmdeploy.apis.pytorch2onnx.torch2onnx in subprocess
# 09/17 23:09:41 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "Codebases" registry tree. As a workaround, the current "Codebases" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:09:41 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "mmseg_tasks" registry tree. As a workaround, the current "mmseg_tasks" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/builder.py:36: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn('``build_loss`` would be deprecated soon, please use '
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/losses/cross_entropy_loss.py:235: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmsegmentation/v0.5/deeplabv3plus/deeplabv3plus_r50-d8_512x512_80k_ade20k/deeplabv3plus_r50-d8_512x512_80k_ade20k_20200614_185028-bf1400d8.pth
# 09/17 23:09:42 - mmengine - WARNING - DeprecationWarning: get_onnx_config will be deprecated in the future.
# 09/17 23:09:42 - mmengine - INFO - Export PyTorch model to ONNX: ./outputs/mmseg2onnx_ade20k_deeplabv3+/end2end.onnx.
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/core/optimizers/function_marker.py:160: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   ys_shape = tuple(int(s) for s in ys.shape)
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/codebase/mmseg/models/segmentors/base.py:61: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if seg_logit.shape[1] == 1:
# 09/17 23:09:45 - mmengine - INFO - Execute onnx optimize passes.
# 09/17 23:09:45 - mmengine - WARNING - Can not optimize model, please build torchscipt extension.
# More details: https://github.com/open-mmlab/mmdeploy/tree/main/docs/en/experimental/onnx_optimizer.md
# ============= Diagnostic Run torch.onnx.export version 2.0.0+cu117 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# 09/17 23:09:45 - mmengine - INFO - Finish pipeline mmdeploy.apis.pytorch2onnx.torch2onnx
# 09/17 23:09:45 - mmengine - INFO - Start pipeline mmdeploy.apis.utils.utils.to_backend in main process
# 09/17 23:09:45 - mmengine - INFO - Finish pipeline mmdeploy.apis.utils.utils.to_backend
# 09/17 23:09:45 - mmengine - INFO - visualize onnxruntime model start.
# 09/17 23:09:47 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "Codebases" registry tree. As a workaround, the current "Codebases" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:09:47 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "mmseg_tasks" registry tree. As a workaround, the current "mmseg_tasks" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:09:47 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "backend_segmentors" registry tree. As a workaround, the current "backend_segmentors" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:09:47 - mmengine - INFO - Successfully loaded onnxruntime custom ops from /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/lib/libmmdeploy_onnxruntime_ops.so
# 09/17 23:09:49 - mmengine - INFO - visualize onnxruntime model success.
# 09/17 23:09:49 - mmengine - INFO - visualize pytorch model start.
# 09/17 23:09:51 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "Codebases" registry tree. As a workaround, the current "Codebases" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:09:51 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "mmseg_tasks" registry tree. As a workaround, the current "mmseg_tasks" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/builder.py:36: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn('``build_loss`` would be deprecated soon, please use '
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/losses/cross_entropy_loss.py:235: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmsegmentation/v0.5/deeplabv3plus/deeplabv3plus_r50-d8_512x512_80k_ade20k/deeplabv3plus_r50-d8_512x512_80k_ade20k_20200614_185028-bf1400d8.pth
# 09/17 23:09:55 - mmengine - INFO - visualize pytorch model success.
# 09/17 23:09:55 - mmengine - INFO - All process success.

# %% [markdown]
# ### MaskFormer

# %%
# !python ./mmdeploy/tools/deploy.py \
#     ./mmdeploy/configs/mmseg/segmentation_onnxruntime_dynamic.py \
#     './mmsegmentation/configs/maskformer/maskformer_swin-s_upernet_8xb2-160k_ade20k-512x512.py' \
#     'https://download.openmmlab.com/mmsegmentation/v0.5/maskformer/maskformer_swin-s_upernet_8xb2-160k_ade20k-512x512/maskformer_swin-s_upernet_8xb2-160k_ade20k-512x512_20221115_114710-723512c7.pth' \
#     ./data/bedroom_1.jpeg \
#     --work-dir ./outputs/mmseg2onnx_ade20K_maskformer \
#     --dump-info
# Out:
# 09/17 23:11:46 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "Codebases" registry tree. As a workaround, the current "Codebases" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:11:46 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "mmseg_tasks" registry tree. As a workaround, the current "mmseg_tasks" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:11:47 - mmengine - INFO - Start pipeline mmdeploy.apis.pytorch2onnx.torch2onnx in subprocess
# 09/17 23:11:48 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "Codebases" registry tree. As a workaround, the current "Codebases" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:11:48 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "mmseg_tasks" registry tree. As a workaround, the current "mmseg_tasks" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmsegmentation/v0.5/maskformer/maskformer_swin-s_upernet_8xb2-160k_ade20k-512x512/maskformer_swin-s_upernet_8xb2-160k_ade20k-512x512_20221115_114710-723512c7.pth
# 09/17 23:11:48 - mmengine - WARNING - DeprecationWarning: get_onnx_config will be deprecated in the future.
# 09/17 23:11:48 - mmengine - INFO - Export PyTorch model to ONNX: ./outputs/mmseg2onnx_ade20K_maskformer/end2end.onnx.
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/core/optimizers/function_marker.py:160: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   ys_shape = tuple(int(s) for s in ys.shape)
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/utils/embed.py:62: TracerWarning: Converting a tensor to a Python float might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   output_h = math.ceil(input_h / stride_h)
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/utils/embed.py:63: TracerWarning: Converting a tensor to a Python float might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   output_w = math.ceil(input_w / stride_w)
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/utils/embed.py:64: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   pad_h = max((output_h - 1) * stride_h +
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/utils/embed.py:66: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   pad_w = max((output_w - 1) * stride_w +
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/utils/embed.py:72: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if pad_h > 0 or pad_w > 0:
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/backbones/swin.py:183: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert L == H * W, 'input feature has wrong size'
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/backbones/swin.py:266: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   B = int(windows.shape[0] / (H * W / window_size / window_size))
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/backbones/swin.py:248: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if pad_r > 0 or pad_b:
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmcv/cnn/bricks/wrappers.py:167: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if x.numel() == 0 and obsolete_torch_version(TORCH_VERSION, (1, 5)):
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/pytorch/functions/tensor_setitem.py:38: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   stop = stop if stop >= 0 else self_shape[i] + stop
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/utils/embed.py:306: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert L == H * W, 'input feature has wrong size'
# ============= Diagnostic Run torch.onnx.export version 2.0.0+cu117 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# Process Process-2:
# Traceback (most recent call last):
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/core/pipeline_manager.py", line 107, in __call__
#     ret = func(*args, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/pytorch2onnx.py", line 98, in torch2onnx
#     export(
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/core/pipeline_manager.py", line 356, in _wrap
#     return self.call_function(func_name_, *args, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/core/pipeline_manager.py", line 326, in call_function
#     return self.call_function_local(func_name, *args, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/core/pipeline_manager.py", line 275, in call_function_local
#     return pipe_caller(*args, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/core/pipeline_manager.py", line 107, in __call__
#     ret = func(*args, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/onnx/export.py", line 131, in export
#     torch.onnx.export(
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/onnx/utils.py", line 506, in export
#     _export(
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/onnx/utils.py", line 1548, in _export
#     graph, params_dict, torch_out = _model_to_graph(
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/onnx/optimizer.py", line 27, in model_to_graph__custom_optimizer
#     graph, params_dict, torch_out = ctx.origin_func(*args, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/onnx/utils.py", line 1113, in _model_to_graph
#     graph, params, torch_out, module = _create_jit_graph(model, args)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/onnx/utils.py", line 989, in _create_jit_graph
#     graph, torch_out = _trace_and_get_graph_from_model(model, args)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/onnx/utils.py", line 893, in _trace_and_get_graph_from_model
#     trace_graph, torch_out, inputs_states = torch.jit._get_trace_graph(
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/jit/_trace.py", line 1268, in _get_trace_graph
#     outs = ONNXTracedModule(f, strict, _force_outplace, return_inputs, _return_inputs_states)(*args, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/jit/_trace.py", line 127, in forward
#     graph, out = torch._C._create_graph_by_tracing(
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/jit/_trace.py", line 118, in wrapper
#     outs.append(self.inner(*trace_inputs))
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1488, in _slow_forward
#     result = self.forward(*input, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/onnx/export.py", line 123, in wrapper
#     return forward(*arg, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/codebase/mmseg/models/segmentors/base.py", line 51, in base_segmentor__forward
#     seg_logit = self.predict(inputs, data_samples)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/codebase/mmseg/models/segmentors/encoder_decoder.py", line 26, in encoder_decoder__predict
#     seg_logit = self.decode_head.predict(x, batch_img_metas, self.test_cfg)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/decode_heads/maskformer_head.py", line 155, in predict
#     batch_data_samples.append(SegDataSample(metainfo=metainfo))
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmengine/structures/base_data_element.py", line 216, in __init__
#     self.set_metainfo(metainfo=metainfo)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmengine/structures/base_data_element.py", line 231, in set_metainfo
#     meta = copy.deepcopy(metainfo)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/copy.py", line 146, in deepcopy
#     y = copier(x, memo)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/copy.py", line 231, in _deepcopy_dict
#     y[deepcopy(key, memo)] = deepcopy(value, memo)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/copy.py", line 172, in deepcopy
#     y = _reconstruct(x, memo, *rv)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/copy.py", line 265, in _reconstruct
#     y = func(*args)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/copy.py", line 264, in <genexpr>
#     args = (deepcopy(arg, memo) for arg in args)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/copy.py", line 146, in deepcopy
#     y = copier(x, memo)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/copy.py", line 211, in _deepcopy_tuple
#     y = [deepcopy(a, memo) for a in x]
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/copy.py", line 211, in <listcomp>
#     y = [deepcopy(a, memo) for a in x]
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/copy.py", line 153, in deepcopy
#     y = copier(memo)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/_tensor.py", line 118, in __deepcopy__
#     new_storage = self._typed_storage()._deepcopy(memo)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/storage.py", line 661, in _deepcopy
#     return self._new_wrapped_storage(copy.deepcopy(self._untyped_storage, memo))
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/copy.py", line 153, in deepcopy
#     y = copier(memo)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/storage.py", line 98, in __deepcopy__
#     new_storage = self.clone()
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/storage.py", line 112, in clone
#     return type(self)(self.nbytes(), device=self.device).copy_(self)
# RuntimeError: NYI: Named tensors are not supported with the tracer
# 09/17 23:11:51 - mmengine - ERROR - /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/core/pipeline_manager.py - pop_mp_output - 80 - `mmdeploy.apis.pytorch2onnx.torch2onnx` with Call id: 0 failed. exit.

# %% [markdown]
# ### Mask2Former

# %%
# !python ./mmdeploy/tools/deploy.py \
#     ./mmdeploy/configs/mmseg/segmentation_onnxruntime_dynamic.py \
#     './mmsegmentation/configs/mask2former/mask2former_swin-b-in1k-384x384-pre_8xb2-160k_ade20k-640x640.py' \
#     'https://download.openmmlab.com/mmsegmentation/v0.5/mask2former/mask2former_swin-b-in1k-384x384-pre_8xb2-160k_ade20k-640x640/mask2former_swin-b-in1k-384x384-pre_8xb2-160k_ade20k-640x640_20221129_125118-a4a086d2.pth' \
#     ./data/bedroom_1.jpeg \
#     --work-dir ./outputs/mmseg2onnx_ade20K_mask2former \
#     --dump-info
# Out:
# 09/17 23:12:40 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "Codebases" registry tree. As a workaround, the current "Codebases" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:12:40 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "mmseg_tasks" registry tree. As a workaround, the current "mmseg_tasks" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:12:42 - mmengine - INFO - Start pipeline mmdeploy.apis.pytorch2onnx.torch2onnx in subprocess
# 09/17 23:12:42 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "Codebases" registry tree. As a workaround, the current "Codebases" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# 09/17 23:12:42 - mmengine - WARNING - Failed to search registry with scope "mmseg" in the "mmseg_tasks" registry tree. As a workaround, the current "mmseg_tasks" registry in "mmdeploy" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmseg" is a correct scope, or whether the registry is initialized.
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmsegmentation/v0.5/mask2former/mask2former_swin-b-in1k-384x384-pre_8xb2-160k_ade20k-640x640/mask2former_swin-b-in1k-384x384-pre_8xb2-160k_ade20k-640x640_20221129_125118-a4a086d2.pth
# 09/17 23:12:43 - mmengine - WARNING - DeprecationWarning: get_onnx_config will be deprecated in the future.
# 09/17 23:12:43 - mmengine - INFO - Export PyTorch model to ONNX: ./outputs/mmseg2onnx_ade20K_mask2former/end2end.onnx.
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/core/optimizers/function_marker.py:160: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   ys_shape = tuple(int(s) for s in ys.shape)
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/utils/embed.py:62: TracerWarning: Converting a tensor to a Python float might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   output_h = math.ceil(input_h / stride_h)
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/utils/embed.py:63: TracerWarning: Converting a tensor to a Python float might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   output_w = math.ceil(input_w / stride_w)
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/utils/embed.py:64: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   pad_h = max((output_h - 1) * stride_h +
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/utils/embed.py:66: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   pad_w = max((output_w - 1) * stride_w +
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/utils/embed.py:72: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if pad_h > 0 or pad_w > 0:
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/backbones/swin.py:183: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert L == H * W, 'input feature has wrong size'
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/backbones/swin.py:266: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   B = int(windows.shape[0] / (H * W / window_size / window_size))
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/backbones/swin.py:248: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if pad_r > 0 or pad_b:
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmcv/cnn/bricks/wrappers.py:167: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if x.numel() == 0 and obsolete_torch_version(TORCH_VERSION, (1, 5)):
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/pytorch/functions/tensor_setitem.py:38: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   stop = stop if stop >= 0 else self_shape[i] + stop
# /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/utils/embed.py:306: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert L == H * W, 'input feature has wrong size'
# ============= Diagnostic Run torch.onnx.export version 2.0.0+cu117 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# Process Process-2:
# Traceback (most recent call last):
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/core/pipeline_manager.py", line 107, in __call__
#     ret = func(*args, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/pytorch2onnx.py", line 98, in torch2onnx
#     export(
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/core/pipeline_manager.py", line 356, in _wrap
#     return self.call_function(func_name_, *args, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/core/pipeline_manager.py", line 326, in call_function
#     return self.call_function_local(func_name, *args, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/core/pipeline_manager.py", line 275, in call_function_local
#     return pipe_caller(*args, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/core/pipeline_manager.py", line 107, in __call__
#     ret = func(*args, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/onnx/export.py", line 131, in export
#     torch.onnx.export(
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/onnx/utils.py", line 506, in export
#     _export(
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/onnx/utils.py", line 1548, in _export
#     graph, params_dict, torch_out = _model_to_graph(
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/onnx/optimizer.py", line 27, in model_to_graph__custom_optimizer
#     graph, params_dict, torch_out = ctx.origin_func(*args, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/onnx/utils.py", line 1113, in _model_to_graph
#     graph, params, torch_out, module = _create_jit_graph(model, args)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/onnx/utils.py", line 989, in _create_jit_graph
#     graph, torch_out = _trace_and_get_graph_from_model(model, args)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/onnx/utils.py", line 893, in _trace_and_get_graph_from_model
#     trace_graph, torch_out, inputs_states = torch.jit._get_trace_graph(
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/jit/_trace.py", line 1268, in _get_trace_graph
#     outs = ONNXTracedModule(f, strict, _force_outplace, return_inputs, _return_inputs_states)(*args, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/jit/_trace.py", line 127, in forward
#     graph, out = torch._C._create_graph_by_tracing(
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/jit/_trace.py", line 118, in wrapper
#     outs.append(self.inner(*trace_inputs))
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1488, in _slow_forward
#     result = self.forward(*input, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/onnx/export.py", line 123, in wrapper
#     return forward(*arg, **kwargs)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/codebase/mmseg/models/segmentors/base.py", line 51, in base_segmentor__forward
#     seg_logit = self.predict(inputs, data_samples)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/codebase/mmseg/models/segmentors/encoder_decoder.py", line 26, in encoder_decoder__predict
#     seg_logit = self.decode_head.predict(x, batch_img_metas, self.test_cfg)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/decode_heads/mask2former_head.py", line 146, in predict
#     batch_data_samples = [
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmseg/models/decode_heads/mask2former_head.py", line 147, in <listcomp>
#     SegDataSample(metainfo=metainfo) for metainfo in batch_img_metas
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmengine/structures/base_data_element.py", line 216, in __init__
#     self.set_metainfo(metainfo=metainfo)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmengine/structures/base_data_element.py", line 231, in set_metainfo
#     meta = copy.deepcopy(metainfo)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/copy.py", line 146, in deepcopy
#     y = copier(x, memo)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/copy.py", line 231, in _deepcopy_dict
#     y[deepcopy(key, memo)] = deepcopy(value, memo)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/copy.py", line 172, in deepcopy
#     y = _reconstruct(x, memo, *rv)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/copy.py", line 265, in _reconstruct
#     y = func(*args)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/copy.py", line 264, in <genexpr>
#     args = (deepcopy(arg, memo) for arg in args)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/copy.py", line 146, in deepcopy
#     y = copier(x, memo)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/copy.py", line 211, in _deepcopy_tuple
#     y = [deepcopy(a, memo) for a in x]
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/copy.py", line 211, in <listcomp>
#     y = [deepcopy(a, memo) for a in x]
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/copy.py", line 153, in deepcopy
#     y = copier(memo)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/_tensor.py", line 118, in __deepcopy__
#     new_storage = self._typed_storage()._deepcopy(memo)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/storage.py", line 661, in _deepcopy
#     return self._new_wrapped_storage(copy.deepcopy(self._untyped_storage, memo))
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/copy.py", line 153, in deepcopy
#     y = copier(memo)
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/storage.py", line 98, in __deepcopy__
#     new_storage = self.clone()
#   File "/home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/torch/storage.py", line 112, in clone
#     return type(self)(self.nbytes(), device=self.device).copy_(self)
# RuntimeError: NYI: Named tensors are not supported with the tracer
# 09/17 23:12:47 - mmengine - ERROR - /home/wmy/anaconda3/envs/torch2/lib/python3.10/site-packages/mmdeploy/apis/core/pipeline_manager.py - pop_mp_output - 80 - `mmdeploy.apis.pytorch2onnx.torch2onnx` with Call id: 0 failed. exit.
